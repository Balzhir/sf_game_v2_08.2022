# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sber_data = pd.read_csv('data/sber_data.csv')
sber_data.head()
# Out:
#    id  full_sq  life_sq  floor           sub_area  preschool_quota  \
# 0   1       43     27.0    4.0           Bibirevo           5001.0
# 1   2       34     19.0    3.0  Nagatinskij Zaton           3119.0
# 2   3       43     29.0    2.0     Tekstil'shhiki           1463.0
# 3   4       89     50.0    9.0             Mitino           6839.0
# 4   5       77     77.0    4.0          Basmannoe           3240.0
#
#    preschool_education_centers_raion  school_quota  \
# 0                                  5       11065.0
# 1                                  5        6237.0
# 2                                  4        5580.0
# 3                                  9       17063.0
# 4                                  7        7770.0
#
#    school_education_centers_raion  school_education_centers_top_20_raion  ...  \
# 0                               5                                      0  ...
# 1                               8                                      0  ...
# ...

# %%
display(sber_data.tail())
# Out:
#           id  full_sq  life_sq  floor              sub_area  preschool_quota  \
# 30466  30469       44     27.0    7.0              Otradnoe           5088.0
# 30467  30470       86     59.0    3.0              Tverskoe           1874.0
# 30468  30471       45      NaN   10.0  Poselenie Vnukovskoe              NaN
# 30469  30472       64     32.0    5.0          Obruchevskoe           2372.0
# 30470  30473       43     28.0    1.0           Novogireevo           2215.0
#
#        preschool_education_centers_raion  school_quota  \
# 30466                                  4       12721.0
# 30467                                  4        6772.0
# 30468                                  0           NaN
# 30469                                  6        6083.0
# 30470                                  4        5824.0
#
#        school_education_centers_raion  school_education_centers_top_20_raion  \
# 30466                               4                                      0
# ...

# %%
sber_data['sub_area'].value_counts().to_frame()
# Out:
#                                 sub_area
# Poselenie Sosenskoe                 1776
# Nekrasovka                          1611
# Poselenie Vnukovskoe                1372
# Poselenie Moskovskij                 925
# Poselenie Voskresenskoe              713
# ...                                  ...
# Molzhaninovskoe                        3
# Poselenie Shhapovskoe                  2
# Poselenie Kievskij                     2
# Poselenie Klenovskoe                   1
# Poselenie Mihajlovo-Jarcevskoe         1
#
# [146 rows x 1 columns]

# %%
sber_data.sort_values('price_doc')
# Out:
#           id  full_sq  life_sq  floor               sub_area  preschool_quota  \
# 20244  20247       72     37.0   11.0             Gol'janovo           5041.0
# 1167    1168       38     23.0    9.0        Beskudnikovskoe           2757.0
# 1169    1170       47     31.0    7.0                Savelki           1065.0
# 9221    9224       40     25.0    1.0       Novo-Peredelkino           4249.0
# 3258    3261       31     19.0    5.0               Caricyno           3390.0
# ...      ...      ...      ...    ...                    ...              ...
# 6319    6322      206    128.0    2.0  Pokrovskoe Streshnevo            922.0
# 19095  19098      184     85.0   10.0                Ramenki            903.0
# 7457    7460      185     66.0   33.0                Ramenki            903.0
# 28326  28329      220    144.0    3.0            Presnenskoe           3240.0
# 2118    2121       55     31.0   12.0            Teplyj Stan           4523.0
#
# ...

# %%
hhhhhh = sber_data.groupby('ecology')
hhhhhh.first()
# Out:
#               id  full_sq  life_sq  floor           sub_area  preschool_quota  \
# ecology
# excellent      2       34     19.0    3.0  Nagatinskij Zaton           3119.0
# good           1       43     27.0    4.0           Bibirevo           5001.0
# no data       21       74     44.0   10.0            Vnukovo           1105.0
# poor           3       43     29.0    2.0     Tekstil'shhiki           1463.0
# satisfactory  10       36     21.0    9.0            Kuncevo           4050.0
#
#               preschool_education_centers_raion  school_quota  \
# ecology
# excellent                                     5        6237.0
# good                                          5       11065.0
# no data                                       1        2231.0
# poor                                          4        5580.0
# satisfactory                                  7       11234.0
#
#               school_education_centers_raion  \
# ecology
# ...

# %%
plt.xlabel('kremlin_km')
plt.ylabel('price_doc')
plt.scatter(x=sber_data['kremlin_km'], y=sber_data['price_doc'])
